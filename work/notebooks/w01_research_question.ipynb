# %% [markdown]
# <a href="https://colab.research.google.com/github/charitysamuel972-crypto/amasam/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/charitysamuel972-crypto/amasam/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My lane: Lane 2, Refresh / Content Opportunity Scoring
# Why: This lane connects directly to a decision content teams make weekly —
# which pages deserve review time. It combines numeric signals with a clear
# business action, which fits how I like to think about problems.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: how a content team prioritizes limited review time each week
# Action: someone opens a specific flagged page, checks if it is stale, thin,
# or losing visibility, and decides whether to refresh it
# Cost of a wrong call: if the model flags a fine page, the team wastes review
# time on it. If it misses a page that is truly declining, that page keeps
# losing visibility until the drop becomes much harder to reverse

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("path_to_starter_dataset.csv")  # replace with the real file path/name

print("Total pages:", len(df))
print("Pages flagged as declining:", (df["status"] == "declining").sum())  # adjust column name
print("Pages flagged as stale:", (df["status"] == "stale").sum())  # adjust column name

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What I can claim: this ranking helps prioritize which pages a human reviewer
# should look at first, based on patterns in the data
# What I can't claim: that refreshing a flagged page guarantees better rankings,
# or that the model captures every reason a page might be underperforming
# I am also not using any future-window data as a feature, since that would
# make the results look better than they would be in a real, live setting

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
